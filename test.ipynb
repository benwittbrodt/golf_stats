# %%
# %load_ext autoreload
# %autoreload 2
from garmin_golf import GarminData, GarminToDB
import pandas as pd 


current_db = GarminToDB('golf.db')

to_process = GarminData('golf-export.json')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
to_process.dataset
# Out:
# {'summary': {'pageNumber': 1,
#   'rowsPerPage': 10000,
#   'totalRows': 16,
#   'scorecardSummaries': [{'id': 252512865,
#     'customerId': '6300100637258324',
#     'playerProfileId': 3415146,
#     'scoreType': 'STROKE_PLAY',
#     'courseName': 'Cog Hill Golf & Country Club ~ Blue',
#     'startTime': '2023-08-13T13:58:39.000Z',
#     'endTime': '2023-08-13T18:50:31.000Z',
#     'roundInProgress': False,
#     'strokes': 94,
#     'handicappedStrokes': 78,
#     'scoreWithHandicap': 7,
#     'scoreWithoutHandicap': 23,
#     'holesCompleted': 18,
#     'roundType': 'ALL'},
#    {'id': 252077891,
#     'customerId': '6300100637258324',
#     'playerProfileId': 3415146,
#     'scoreType': 'STROKE_PLAY',
#     'courseName': 'Columbus Park Golf Course',
#     'startTime': '2023-08-10T18:31:54.000Z',
#     'endTime': '2023-08-10T20:17:47.000Z',
#     'roundInProgress': False,
#     'strokes': 40,
#     'handicappedStrokes': 34,
#     'scoreWithHandicap': -1,
# ...
